# %% [markdown]
# ---

# %% [markdown]
# ![Image1.jpg](attachment:Image1.jpg)

# %% [markdown]
# # TP5.0 - Retour sur les notions fondamentales de 1ère NSI - Rappels sur la programmation Python
#
# Durée de l'activité proposé : 2h

# %% [markdown]
# ---

# %% [markdown]
# ## Utilisation du notebook
#
# Pour cette première séance, nous allons utiliser Python en mode "notebook". Le fichier que vous venez d'ouvrir, "Rappels sur la programmation Python.ipynb", et qui est affiché ici-même, est un notebook. Faites-en une copie avec la commande ci dessus "File>Make a Copy...", et renommez-le en cliquant sur le titre (à côté de jupyter Rappels...), en rajoutant votre nom.
#
# Le notebook est très pratique ! On peut entrer des expressions (opérations, calculs) ou des instructions (des commandes) dans tous les champs ci-dessous qui commencent par `In[..]`. Pour entrer plusieurs lignes à la suite, on appuie sur la touche entrée.
#
# Le résultat s'obtient avec :
# * ctrl + entrée, dans ce cas on reste dans la cellule courante;
# * majusucule + entrée, dans ce cas on passe à la cellule suivante.
# * Après exécution, le résultat d'un programme est souvent précédé de Out[ ].
#
# Il est possible qu'un notebook ne réponde plus lors de la tentative d'éxécution d'une commande ou d'un programme. C'est notamment le cas lorsqu'un programme précédent a planté. Commencez par sauver votre travail. Puis allez dans l'onglet "File", et fermez le TD : cocher la case correspondante, "shutdown" en haut de la page. Fermez ensuite l'onglet du TD, et relancez-le à partir de "Home".
#
#
# ## Introduction : Python ?
#
#
# En classe de **Première**, vous avez découvert la notion d’algorithme, et vous avez normalement dû implémenter ces algorithmes à l’aide d’un langage de programmation.
#
# Si tout se passe bien, vous avez donc dû principalement découvrir le langage Python.
#
# Alors pourquoi Python ? Quelques pistes de réflexion non-exhaustives :
#
# -	Python est un langage de programmation interprété, c'est-à-dire qu'il n'est pas nécessaire de le compiler avant de l'exécute
#
# - Python est un langage facile à apprendre et son code est plus lisible, il est donc plus facile à maintenir. Il est parfois jusqu'à 5 fois plus concis que le langage Java par exemple, ce qui augmente la productivité du développeur et réduit mécaniquement le nombre de bugs.
#
# - L'environnement python est riche en librairies, et possède pas mal de documentation.
#
# - Python est également très utilisé dans les milieux scientifiques, et vous utiliserez certainement Python en Sciences Physiques très prochainement.
#
#
# En classe de **Terminale**, nous allons reprendre les bases vues en classe de Première et nous en servir pour aller plus loin dans la découverte des structures, mais nous allons également aller plus loin dans la découverte de certains algorithmes.
#
# Dans ce Premier TP, vous trouverez une succession d’exercices à travailler seul et en autonomie. L’objectif est donc de se rappeler quelques notions de bases vues en classe de Première, et de vous permettre de vous remettre dans le rythme.
#
# Bien entendu, vous avez le droit d’utiliser tout document ( ou ressource) susceptible de vous aider.
#
# Une fiche récapitulative des notions vues en classe de Première vous est donné avec ce TP. Mais le contenu n'est pas exhaustif.
#
#
# **Bon travail à tous !**

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 1
# ![Image2.jpg](attachment:Image2.jpg)

# %%
#Votre réponse :

print("toto")
# Out:
# toto

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 2
# ![Image3.jpg](attachment:Image3.jpg)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 3
# ![Image4.jpg](attachment:Image4.jpg)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 4
# ![Image5.png](attachment:Image5.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 5
# ![Image6.png](attachment:Image6.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 6
# ![Image7.png](attachment:Image7.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 7
# ![Image8.png](attachment:Image8.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 8
# ![Image9.png](attachment:Image9.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 9
# ![Image10.png](attachment:Image10.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 10
# ![Image12.png](attachment:Image12.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 11
# ![Image13.png](attachment:Image13.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 12
# ![Image14.png](attachment:Image14.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# ### Exercice 13
# ![Image15.png](attachment:Image15.png)

# %%
#Votre réponse :

# %% [markdown]
# ---

# %% [markdown]
# | <span style='color:Blue'> L.HELIN |  | |   | |     |<span style='color:Blue'> NSI Terminale | |   | ||<span style='color:Blue'> Lycée Ozanam (Lille) & Lycée NDPO (Orchies)|
# | --- | --- |--- |--- |--- |--- | --- | --- |--- |--- | --- | --- |
